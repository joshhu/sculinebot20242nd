# %%
import os
from pyngrok import ngrok

# %%
ngrok_autotoken = os.environ.get('NGROK_AUTHTOKEN')
port = 5051

# %%
ngrok.kill()

# %%
ngrok.set_auth_token(ngrok_autotoken)
tunnel = ngrok.connect(port, name="linebot_tunnel")
print(tunnel.public_url)

# %%
ngrok.kill()
